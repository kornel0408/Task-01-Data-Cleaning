# %%
# ****************************************************************************************
#                            Task1 : Data Cleaning
# ****************************************************************************************

# %%
# ----------------------------------
#         Importing Libraries
# ----------------------------------

# %%
import pandas as pd

# %%
# ----------------------------------
#        Loading Dataset
# ----------------------------------

# %%
df = pd.read_csv(r"C:\Users\boyal\OneDrive\ElevateLabs_Internship\Task_01\01_Data\netflix_titles_raw_data.csv")

# %%
# ----------------------------------
#     understanding data set
# ----------------------------------

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# ----------------------------------
#      Checking Duplicates
# ----------------------------------

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# ----------------------------------
#        Checking null values
# ----------------------------------

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
blank_values = (df["director"]=="").sum()
print(blank_values)
# Out:
# 0

# %%
# ----------------------------------
#         Null handling
# ----------------------------------

# %%
df["director"].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
df["director"].nunique()
# Out:
# 4528

# %%
df["director"] = df["director"].fillna("Unknown")

# %%
df["director"].isna().sum()
# Out:
# np.int64(0)

# %%
df["cast"].nunique()
# Out:
# 7692

# %%
df["cast"] = df["cast"].fillna("Unknown")

# %%
df["cast"].isna().sum()
# Out:
# np.int64(0)

# %%
df['country'] = df['country'].fillna("Unknown")

# %%
df["country"].isna().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset="date_added")

# %%
df["date_added"].isna().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset="rating")

# %%
df["rating"].isna().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset="duration")
df["duration"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# ----------------------------------
#    assinging proper data types
# ----------------------------------

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
cols = ["type", "director", "cast", "country", "rating", "listed_in", "description"]
df[cols] = df[cols].astype("string")

# %%
df["date_added"] = df["date_added"].str.strip()

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df["date_added"].head()
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# show_id                 object
# type            string[python]
# title                   object
# director        string[python]
# cast            string[python]
# country         string[python]
# date_added      datetime64[ns]
# release_year             int64
# rating          string[python]
# duration                object
# listed_in       string[python]
# description     string[python]
# dtype: object

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df.to_csv(
    r"C:\Users\boyal\OneDrive\ElevateLabs_Internship\Task_01\01_Data\netflix_cleaned_data.csv",
    index=False
)
